# %%
from model import *
from dataset import *
import math


seed = 0
np.random.seed(seed)
torch.manual_seed(seed)

torch.set_default_tensor_type(torch.DoubleTensor)

device = 'cpu'

p = 59
embd_dim = 10
input_token = 2
vocab_size = p

#model_mode = 'standard'
#model_mode = 'ip'
model_mode = 'hs1'

if model_mode == 'ip':
    # ip model
    unembd = True
    weight_tied = True
    hidden_size = 100
    shp = [input_token * embd_dim, hidden_size, embd_dim, vocab_size]
    model = MLP(shp=shp, vocab_size=vocab_size, embd_dim=embd_dim, input_token=input_token, unembd=unembd, weight_tied=weight_tied, seed=seed).to(device)
elif model_mode == 'hs3':
    weight_tied = True
    hidden_size = 100
    shp = [input_token * embd_dim, hidden_size, embd_dim, vocab_size]
    model = MLP_HS(shp=shp, vocab_size=vocab_size, embd_dim=embd_dim, input_token=input_token, weight_tied=weight_tied, seed=seed, n=1).to(device)
elif model_mode == 'hs2':
    weight_tied = True
    hidden_size = 100
    shp = [input_token * embd_dim, hidden_size, embd_dim, vocab_size]
    model = MLP_HS(shp=shp, vocab_size=vocab_size, embd_dim=embd_dim, input_token=input_token, weight_tied=weight_tied, seed=seed, n=math.sqrt(embd_dim)).to(device)
elif model_mode == 'hs1':
    weight_tied = True
    hidden_size = 100
    shp = [input_token * embd_dim, hidden_size, embd_dim, vocab_size]
    model = MLP_HS(shp=shp, vocab_size=vocab_size, embd_dim=embd_dim, input_token=input_token, weight_tied=weight_tied, seed=seed, n=embd_dim).to(device)
elif model_mode == 'standard':
    unembd = False
    weight_tied = False
    hidden_size = 100
    shp = [input_token * embd_dim, hidden_size, hidden_size, vocab_size]
    #shp = [input_token * embd_dim, hidden_size, vocab_size]
    model = MLP(shp=shp, vocab_size=vocab_size, embd_dim=embd_dim, input_token=input_token, unembd=unembd, weight_tied=weight_tied, seed=seed).to(device)
else:
    print('model_mode not recognized!')
    
    
# data
dataset = modular_addition_dataset(p=p)
#dataset = repeat_dataset(dataset)
dataset = split_dataset(dataset, train_ratio=0.8, seed=seed)

### train ###
wd = 0.0
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=wd)
steps = 4001 #4001
log = 200

train_losses = []
test_losses = []
train_accs = []
test_accs = []

embds = []

lamb = 0.1

for step in range(steps):
        
    optimizer.zero_grad()
    
    logits = model.pred_logit(dataset['train_data_id'])
    loss = torch.nn.functional.cross_entropy(logits, dataset['train_label'])
    
    embd_reg = torch.mean(torch.sqrt(torch.mean(model.embedding**2, dim=0)))
    total_loss = loss + lamb * embd_reg
    
    acc = torch.mean((torch.argmax(logits, dim=1) == dataset['train_label']).float())

    train_losses.append(loss.item())
    train_accs.append(acc.item())
    
    logits_test = model.pred_logit(dataset['test_data_id'])
    loss_test = torch.nn.functional.cross_entropy(logits_test, dataset['test_label'])

    acc_test = torch.mean((torch.argmax(logits_test, dim=1) == dataset['test_label']).float())

    test_losses.append(loss_test.item())
    test_accs.append(acc_test.item())

    #total_loss = loss
    total_loss.backward()
    optimizer.step()

    if step % log == 0:
        print("step = %d | total loss: %.2e | train loss: %.2e | test loss %.2e | train acc: %.2e | test acc: %.2e "%(step, total_loss.cpu().detach().numpy(), loss.cpu().detach().numpy(), loss_test.cpu().detach().numpy(), acc.cpu().detach().numpy(), acc_test.cpu().detach().numpy()))

    if step % 100 == 0:
        embds.append(model.embedding.cpu().detach().numpy())
# Out:
# step = 0 | total loss: 9.02e+00 | train loss: 9.01e+00 | test loss 8.98e+00 | train acc: 1.51e-02 | test acc: 2.15e-02
# step = 200 | total loss: 4.08e+00 | train loss: 4.06e+00 | test loss 4.17e+00 | train acc: 2.51e-02 | test acc: 4.30e-03
# step = 400 | total loss: 4.07e+00 | train loss: 4.05e+00 | test loss 4.17e+00 | train acc: 2.77e-02 | test acc: 4.30e-03
# step = 600 | total loss: 4.01e+00 | train loss: 4.00e+00 | test loss 4.19e+00 | train acc: 3.70e-02 | test acc: 7.17e-03
# step = 800 | total loss: 3.67e+00 | train loss: 3.65e+00 | test loss 4.00e+00 | train acc: 6.68e-02 | test acc: 2.01e-02
# step = 1000 | total loss: 2.12e+00 | train loss: 2.10e+00 | test loss 2.56e+00 | train acc: 3.31e-01 | test acc: 1.65e-01
# step = 1200 | total loss: 5.57e-02 | train loss: 3.42e-02 | test loss 6.30e-02 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 1400 | total loss: 2.64e-02 | train loss: 5.17e-03 | test loss 1.20e-02 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 1600 | total loss: 2.30e-02 | train loss: 2.00e-03 | test loss 5.14e-03 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 1800 | total loss: 2.18e-02 | train loss: 1.07e-03 | test loss 2.89e-03 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 2000 | total loss: 2.11e-02 | train loss: 6.79e-04 | test loss 1.88e-03 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 2200 | total loss: 2.06e-02 | train loss: 4.81e-04 | test loss 1.34e-03 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 2400 | total loss: 2.01e-02 | train loss: 3.70e-04 | test loss 1.02e-03 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 2600 | total loss: 1.97e-02 | train loss: 3.01e-04 | test loss 8.18e-04 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 2800 | total loss: 1.92e-02 | train loss: 2.57e-04 | test loss 6.82e-04 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 3000 | total loss: 1.87e-02 | train loss: 2.26e-04 | test loss 5.88e-04 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 3200 | total loss: 1.83e-02 | train loss: 2.04e-04 | test loss 5.19e-04 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 3400 | total loss: 1.77e-02 | train loss: 1.87e-04 | test loss 4.66e-04 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 3600 | total loss: 1.72e-02 | train loss: 1.74e-04 | test loss 4.26e-04 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 3800 | total loss: 1.66e-02 | train loss: 1.64e-04 | test loss 3.93e-04 | train acc: 1.00e+00 | test acc: 1.00e+00
# step = 4000 | total loss: 1.60e-02 | train loss: 1.56e-04 | test loss 3.66e-04 | train acc: 1.00e+00 | test acc: 1.00e+00

# %%
import matplotlib.pyplot as plt

plt.plot(train_accs)
plt.plot(test_accs)
plt.legend(['train', 'test'])
plt.xlabel('steps')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %% [markdown]
# Sample complexity is interesting (study dependence on num)! It seems that hs is more sample efficient than ip and standard!
# Embd_dim is also an important hyperparam. Different methods need different lamb as well.

# %%
import numpy as np
from sklearn.decomposition import PCA
embd = model.embedding.cpu().detach().numpy()
X = embd
pca = PCA(n_components=embd_dim)
pca.fit(X)
embd_t = pca.fit_transform(X)

# %%
pca.explained_variance_ratio_
# Out:
# array([3.37909686e-01, 3.03079741e-01, 1.84100159e-01, 1.69918152e-01,
#        4.49023991e-03, 4.61384045e-04, 3.17489562e-05, 8.88116528e-06,
#        6.46347223e-09, 1.74397587e-09])

# %%
active_pca_dim = np.sum(pca.explained_variance_ratio_ > 1e-4)

# %%
torch.mean(model.embedding**2, dim=0)
# Out:
# tensor([3.9034e-02, 1.3657e-02, 6.2578e-02, 2.2129e-04, 3.3562e-09, 4.0956e-02,
#         8.1965e-02, 2.4340e-09, 1.9244e-04, 8.7015e-02],
#        grad_fn=<MeanBackward1>)

# %%
import copy
import matplotlib.pyplot as plt

embd = model.embedding.cpu().detach().numpy()

dim1 = 0
dim2 = 1

plt.scatter(embd_t[:,dim1], embd_t[:,dim2])


for i in range(p):
    plt.text(embd_t[i,dim1], embd_t[i,dim2], i)

# %%
#%matplotlib widget

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import mpld3

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Data for the plot (example)
x = embd_t[:,0]
y = embd_t[:,1]
z = embd_t[:,2]

ax.scatter(x, y, z)

ax.set_zlim(-1,1)

# Add text annotation
for i in range(25):
    ax.text(embd_t[i,0], embd_t[i,1], embd_t[i,2], i, color='black')

#plt.show()
ax.view_init(0,0)

# %%
active_embd_dim = torch.sum(torch.mean(model.embedding**2, dim=0) > 1e-4).item()

# %%
active_pca_dim, active_embd_dim
# Out:
# (3, 4)

# %%
inputs = embd[dataset['train_data_id']]
output = (- inputs[:,0,:] + inputs[:,1,:] + inputs[:,2,:])

xx = np.linalg.norm(output, axis=1)[:,None]**2
ww = np.linalg.norm(embd, axis=1)[None,:]**2
wx = output @ embd.T
distsq = ww + xx - 2 * wx
acc = np.mean(np.argmin(distsq, axis=1) == dataset['train_label'].cpu().detach().numpy())

# %%
import copy
import matplotlib.pyplot as plt

embd = model.embedding.cpu().detach().numpy()

dim1 = 0
dim2 = 1

plt.scatter(embd[:,dim1], embd[:,dim2])


for i in range(p**2):
    plt.text(embd[i,dim1], embd[i,dim2], i)
    
i = 0
dp = torch.cat([dataset['train_data_id'][[i]], dataset['train_label'][[i]][:,None]], dim=1)[0]
cor = embd[dp.cpu().detach().numpy()][:,[dim1, dim2]]
cor2 = copy.deepcopy(cor[2])
cor3 = copy.deepcopy(cor[3])
cor[2] = cor3
cor[3] = cor2
cor = np.concatenate([cor, cor[[0],:]], axis=0)
plt.plot(cor[:,0], cor[:,1], color='red')

# %%
#plt.subplot(10,10,1)
import copy

plt.figure(figsize=(20,20))

dim1 = 0
dim2 = 1

for i in range(100):
    plt.subplot(10,10,i+1)
    plt.scatter(embd[:,dim1], embd[:,dim2], s=10)
    dp = torch.cat([dataset['train_data_id'][[i]], dataset['train_label'][[i]][:,None]], dim=1)[0]
    cor = embd[dp.cpu().detach().numpy()][:,[dim1, dim2]]
    cor2 = copy.deepcopy(cor[2])
    cor3 = copy.deepcopy(cor[3])
    cor[2] = cor3
    cor[3] = cor2
    cor = np.concatenate([cor, cor[[0],:]], axis=0)
    plt.plot(cor[:,0], cor[:,1], color='red')

# %%
# analyze data
import numpy as np
import matplotlib.pyplot as plt

#model_mode = 'standard'
#model_mode = 'hs2'
model_mode = 'hs1'
#model_mode = 'ip'

embd_dims = [1,2,3,4,5,10,20,50]

lamb = 0.0
seed = 0

train_accs = []
test_accs = []
pca_dims = []

for embd_dim in embd_dims:
    
    #data = np.loadtxt('./results/modadd/model_%s_embddim_%d_lamb_%.2f_seed_%d_p_59_performance.txt'%(model_mode, embd_dim, lamb, seed))
    data = np.loadtxt('./results/modadd_largeinit/model_%s_embddim_%d_lamb_%.2f_seed_%d_p_59_performance.txt'%(model_mode, embd_dim, lamb, seed))
    train_accs.append(data[0])
    test_accs.append(data[1])
    pca_dims.append(data[2])

# %%
plt.figure(figsize=(18,3))

plt.subplot(1,3,1)

plt.plot(embd_dims, train_accs, marker='o')

plt.plot(embd_dims, np.array(train_accs)*0+1, ls='--', color='black')
    
plt.xlabel('embd dim')
plt.ylabel('train acc')
plt.xscale('log')
plt.ylim(-0.1,1.1)

plt.subplot(1,3,2)

plt.plot(embd_dims, test_accs, marker='o')
    
plt.plot(embd_dims, np.array(test_accs)*0+1, ls='--', color='black')
    
plt.xlabel('embd dim')
plt.ylabel('test acc')
plt.xscale('log')
plt.ylim(-0.1,1.1)

plt.subplot(1,3,3)

plt.plot(embd_dims, pca_dims, marker='o')
    
plt.xlabel('embd dim')
plt.ylabel('pca dimension')
plt.xscale('log')
plt.yscale('log')


plt.suptitle('MLP (harmonic similarity)', fontsize=15)
#plt.suptitle(f'MLP (inner product)', fontsize=15)
#plt.suptitle('MLP (standard)', fontsize=15)
# Out:
# Text(0.5, 0.98, 'MLP (harmonic similarity)')
